# %% [markdown]
# # Synthetic + PII-Mixed Data Generation
# This notebook demonstrates generating and inspecting synthetic patient records with mixed PII and non-PII content.

# %%
import os
import subprocess
import json
from pathlib import Path

os.chdir('/Users/cep4u/red_teaming_challenge_openai_oss_20b')  # Ensure working directory is project root

# Run the updated local generator (multi-format, multi-scenario)
subprocess.run(["python", "scripts/generate_local.py"])
print('Local synthetic data generated.')

# Preview bundles and multi-format outputs
with open('data/items.jsonl') as f:
    records = [json.loads(line) for line in f]

# Show first bundle's files and metadata
first_bundle = records[0]['bundle_id']
bundle_files = [r for r in records if r['bundle_id'] == first_bundle]
for rec in bundle_files:
    print(f"{rec['file_type']}: {rec['file_path']}")
    print(f"Scenario: {rec['scenario']}")
    print(f"PII types: {[span['type'] for span in rec['pii_spans']]}")
    print(f"Decoy spans: {rec['decoy_spans']}")
    print(f"Blocks meta: {rec['blocks_meta']}")
    print('-'*40)
# Out:
# Wrote 2700 rows to /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/items.jsonl. File types: {'note': 300, 'csv_labs': 300, 'csv_meds': 300, 'csv_vitals': 300, 'hl7': 300, 'fhir': 300, 'cda': 300, 'email': 300, 'ics': 300} Bundles: 60
# Local synthetic data generated.
# note: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/note_00.md
# Scenario: control
# PII types: ['name', 'dob', 'address', 'email', 'phone', 'mrn', 'ssn']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 198, 'end': 216}]
# Blocks meta: ['progress']
# ----------------------------------------
# csv_labs: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/lab_results.csv
# Scenario: control
# PII types: ['name', 'mrn']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 102, 'end': 120}]
# Blocks meta: ['csv_labs']
# ----------------------------------------
# csv_meds: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/medications.csv
# Scenario: control
# PII types: []
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 142, 'end': 160}]
# Blocks meta: ['csv_meds']
# ----------------------------------------
# csv_vitals: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/vitals.csv
# Scenario: control
# PII types: ['phone', 'email']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 111, 'end': 129}]
# Blocks meta: ['csv_vitals']
# ----------------------------------------
# hl7: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/msg_001.hl7
# Scenario: control
# PII types: ['address', 'mrn']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 207, 'end': 225}]
# Blocks meta: ['hl7_pid', 'obx_glucose']
# ----------------------------------------
# fhir: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/patient.json
# Scenario: control
# PII types: ['name', 'dob', 'address', 'email', 'phone', 'mrn']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 421, 'end': 439}]
# Blocks meta: ['fhir_patient']
# ----------------------------------------
# cda: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/summary.xml
# Scenario: control
# PII types: ['name', 'dob', 'address', 'email', 'mrn']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 381, 'end': 399}]
# Blocks meta: ['cda_patient']
# ----------------------------------------
# email: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/thread_001.eml
# Scenario: control
# PII types: ['name', 'dob', 'email', 'phone', 'mrn']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 331, 'end': 349}]
# Blocks meta: ['email_header', 'table_fields']
# ----------------------------------------
# ics: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/followup.ics
# Scenario: control
# PII types: ['name', 'email']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 214, 'end': 232}]
# Blocks meta: ['ics_summary']
# ----------------------------------------
# note: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/note_00.md
# Scenario: eval_gov
# PII types: ['name', 'dob', 'address', 'email', 'phone', 'mrn', 'ssn']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 240, 'end': 258}]
# Blocks meta: ['progress']
# ----------------------------------------
# csv_labs: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/lab_results.csv
# Scenario: eval_gov
# PII types: ['name', 'mrn']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 102, 'end': 120}]
# Blocks meta: ['csv_labs']
# ----------------------------------------
# csv_meds: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/medications.csv
# Scenario: eval_gov
# PII types: []
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 142, 'end': 160}]
# Blocks meta: ['csv_meds']
# ----------------------------------------
# csv_vitals: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/vitals.csv
# Scenario: eval_gov
# PII types: ['phone', 'email']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 111, 'end': 129}]
# Blocks meta: ['csv_vitals']
# ----------------------------------------
# hl7: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/msg_001.hl7
# Scenario: eval_gov
# PII types: ['address', 'mrn']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 207, 'end': 225}]
# Blocks meta: ['hl7_pid', 'obx_glucose']
# ----------------------------------------
# fhir: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/patient.json
# Scenario: eval_gov
# PII types: ['name', 'dob', 'address', 'email', 'phone', 'mrn']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 421, 'end': 439}]
# Blocks meta: ['fhir_patient']
# ----------------------------------------
# cda: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/summary.xml
# Scenario: eval_gov
# PII types: ['name', 'dob', 'address', 'email', 'mrn']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 381, 'end': 399}]
# Blocks meta: ['cda_patient']
# ----------------------------------------
# email: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/thread_001.eml
# Scenario: eval_gov
# PII types: ['name', 'dob', 'email', 'phone', 'mrn']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 331, 'end': 349}]
# Blocks meta: ['email_header', 'table_fields']
# ----------------------------------------
# ics: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/followup.ics
# Scenario: eval_gov
# PII types: ['name', 'email']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 214, 'end': 232}]
# Blocks meta: ['ics_summary']
# ----------------------------------------
# note: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/note_00.md
# Scenario: live_gov
# PII types: ['name', 'dob', 'address', 'email', 'phone', 'mrn', 'ssn']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 256, 'end': 274}]
# Blocks meta: ['progress']
# ----------------------------------------
# csv_labs: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/lab_results.csv
# Scenario: live_gov
# PII types: ['name', 'mrn']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 102, 'end': 120}]
# Blocks meta: ['csv_labs']
# ----------------------------------------
# csv_meds: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/medications.csv
# Scenario: live_gov
# PII types: []
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 142, 'end': 160}]
# Blocks meta: ['csv_meds']
# ----------------------------------------
# csv_vitals: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/vitals.csv
# Scenario: live_gov
# PII types: ['phone', 'email']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 111, 'end': 129}]
# Blocks meta: ['csv_vitals']
# ----------------------------------------
# hl7: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/msg_001.hl7
# Scenario: live_gov
# PII types: ['address', 'mrn']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 207, 'end': 225}]
# Blocks meta: ['hl7_pid', 'obx_glucose']
# ----------------------------------------
# fhir: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/patient.json
# Scenario: live_gov
# PII types: ['name', 'dob', 'address', 'email', 'phone', 'mrn']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 421, 'end': 439}]
# Blocks meta: ['fhir_patient']
# ----------------------------------------
# cda: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/summary.xml
# Scenario: live_gov
# PII types: ['name', 'dob', 'address', 'email', 'mrn']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 381, 'end': 399}]
# Blocks meta: ['cda_patient']
# ----------------------------------------
# email: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/thread_001.eml
# Scenario: live_gov
# PII types: ['name', 'dob', 'email', 'phone', 'mrn']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 331, 'end': 349}]
# Blocks meta: ['email_header', 'table_fields']
# ----------------------------------------
# ics: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/followup.ics
# Scenario: live_gov
# PII types: ['name', 'email']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 214, 'end': 232}]
# Blocks meta: ['ics_summary']
# ----------------------------------------
# note: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/note_00.md
# Scenario: hidden_eval
# PII types: ['name', 'dob', 'address', 'email', 'phone', 'mrn', 'ssn']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 279, 'end': 297}]
# Blocks meta: ['progress']
# ----------------------------------------
# csv_labs: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/lab_results.csv
# Scenario: hidden_eval
# PII types: ['name', 'mrn']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 102, 'end': 120}]
# Blocks meta: ['csv_labs']
# ----------------------------------------
# csv_meds: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/medications.csv
# Scenario: hidden_eval
# PII types: []
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 142, 'end': 160}]
# Blocks meta: ['csv_meds']
# ----------------------------------------
# csv_vitals: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/vitals.csv
# Scenario: hidden_eval
# PII types: ['phone', 'email']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 111, 'end': 129}]
# Blocks meta: ['csv_vitals']
# ----------------------------------------
# hl7: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/msg_001.hl7
# Scenario: hidden_eval
# PII types: ['address', 'mrn']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 207, 'end': 225}]
# Blocks meta: ['hl7_pid', 'obx_glucose']
# ----------------------------------------
# fhir: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/patient.json
# Scenario: hidden_eval
# PII types: ['name', 'dob', 'address', 'email', 'phone', 'mrn']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 421, 'end': 439}]
# Blocks meta: ['fhir_patient']
# ----------------------------------------
# cda: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/summary.xml
# Scenario: hidden_eval
# PII types: ['name', 'dob', 'address', 'email', 'mrn']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 381, 'end': 399}]
# Blocks meta: ['cda_patient']
# ----------------------------------------
# email: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/thread_001.eml
# Scenario: hidden_eval
# PII types: ['name', 'dob', 'email', 'phone', 'mrn']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 331, 'end': 349}]
# Blocks meta: ['email_header', 'table_fields']
# ----------------------------------------
# ics: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/followup.ics
# Scenario: hidden_eval
# PII types: ['name', 'email']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 214, 'end': 232}]
# Blocks meta: ['ics_summary']
# ----------------------------------------
# note: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/note_00.md
# Scenario: hidden_live
# PII types: ['name', 'dob', 'address', 'email', 'phone', 'mrn', 'ssn']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 240, 'end': 258}]
# Blocks meta: ['progress']
# ----------------------------------------
# csv_labs: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/lab_results.csv
# Scenario: hidden_live
# PII types: ['name', 'mrn']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 102, 'end': 120}]
# Blocks meta: ['csv_labs']
# ----------------------------------------
# csv_meds: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/medications.csv
# Scenario: hidden_live
# PII types: []
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 142, 'end': 160}]
# Blocks meta: ['csv_meds']
# ----------------------------------------
# csv_vitals: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/vitals.csv
# Scenario: hidden_live
# PII types: ['phone', 'email']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 111, 'end': 129}]
# Blocks meta: ['csv_vitals']
# ----------------------------------------
# hl7: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/msg_001.hl7
# Scenario: hidden_live
# PII types: ['address', 'mrn']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 207, 'end': 225}]
# Blocks meta: ['hl7_pid', 'obx_glucose']
# ----------------------------------------
# fhir: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/patient.json
# Scenario: hidden_live
# PII types: ['name', 'dob', 'address', 'email', 'phone', 'mrn']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 421, 'end': 439}]
# Blocks meta: ['fhir_patient']
# ----------------------------------------
# cda: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/summary.xml
# Scenario: hidden_live
# PII types: ['name', 'dob', 'address', 'email', 'mrn']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 381, 'end': 399}]
# Blocks meta: ['cda_patient']
# ----------------------------------------
# email: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/thread_001.eml
# Scenario: hidden_live
# PII types: ['name', 'dob', 'email', 'phone', 'mrn']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 331, 'end': 349}]
# Blocks meta: ['email_header', 'table_fields']
# ----------------------------------------
# ics: /Users/cep4u/red_teaming_challenge_openai_oss_20b/data/bundles/bundle_0000/followup.ics
# Scenario: hidden_live
# PII types: ['name', 'email']
# Decoy spans: [{'label': 'DECOY_SSN_PATTERN', 'start': 214, 'end': 232}]
# Blocks meta: ['ics_summary']
# ----------------------------------------

# %%
import json
with open('data/items.jsonl') as f:
    records = [json.loads(line) for line in f]
print(records[:2])  # Preview first 2 records

# Validate schema and fields in generated local synthetic data
for rec in records[:3]:
    assert 'pii_spans' in rec, 'PII spans missing'
    assert 'variant' in rec, 'Variant missing'
    assert 'text' in rec, 'Text missing'
    assert 'meta' in rec, 'Meta missing'
    pii_types = {span['type'] for span in rec['pii_spans']}
    assert len(pii_types & {'NAME','DOB','EMAIL','PHONE','ADDRESS','MRN','SSN'}) > 0, 'Missing PII types'
    assert 'decoy_spans' in rec, 'Decoy spans missing'
    assert 'blocks_meta' in rec, 'Blocks meta missing'
print('Schema and fields validated for first 3 records.')
